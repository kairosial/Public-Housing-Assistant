# %%
# %pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: c:\Users\USER\.pyenv\pyenv-win\versions\3.13.1\python.exe -m pip install --upgrade pip

# %% [markdown]
# ### 공고문 리스트 불러오기

# %%
import pandas as pd

doc_list = pd.read_excel("./data/doc_list.xlsx")
doc_list
# Out:
#                                                   파일명  \
# 0   (GH)[주택] 25년 1차 기존주택 등 매입임대주택 예비입주자 모집공고(경기도 2...
# 1                 (GH)[주택] 25년 1차 청년매입임대주택 예비입주자 모집공고
# 2                  (LH)(인천) 청년.신혼부부 매입임대리츠주택 입주자 모집공고
# 3                      (LH)2025년 청년 전세임대 1순위 입주자 수시모집
# 4                 (LH)[경기북부] 25년 1차 청년매입임대 예비입주자 모집공고
# 5            (LH)[서울지역본부] 25년 1차 청년 매입임대주택 예비입주자 모집공고
# 6        (LH)[정정공고][경기남부] 25년 1차 청년 매입임대주택 예비입주자 모집공고
# 7            (LH)[정정공고][서울지역본부] 고령자 매입임대주택 예비입주자 모집공고
# 8         (LH)[정정공고][서울지역본부] 기존주택 등 매입임대주택 예비입주자 모집공고
# 9          (LH)[정정공고]구리갈매 이스트힐 10년 공공임대주택 예비입주자 모집 공고
# 10                (LH)[정정공고]전북 남부권 지역 국민임대주택 예비입주자 모집
# 11                (LH)관악봉천 H-1ㆍ2ㆍ3BL 행복주택 입주자격완화 추가모집
# 12                            (LH)군포시 영구임대주택 예비입주자 모집
# 13        (LH)김포한강 Ac-05블록 10년 공공임대주택(리츠) 예비입주자 모집 공고
# 14                         (LH)청년신혼부부매입임대리츠-2502-경기남부
# 15                         (LH)청년신혼부부매입임대리츠-2502-경기북부
# ...

# %%
FILE_NAME = '파일명'
DOC_NAME = '공고명'
COMPANY = '업체'
SITE = '지역'
TARGET = '대상'
KIND = '종류'

# %%
site = '서울'
target = '청년'
kind = '매입임대'
#----------------

# site
filtered_df = doc_list[doc_list[SITE].str.contains(site, na=True)]
filtered_df

# target
filtered_df2 = filtered_df[filtered_df[TARGET].str.contains(target, na=True)]
filtered_df2

# kind
filtered_df3 = filtered_df2[filtered_df2[KIND].str.contains(kind, na=True)]
filtered_df3[FILE_NAME]
# Out:
# 5            (LH)[서울지역본부] 25년 1차 청년 매입임대주택 예비입주자 모집공고
# 8         (LH)[정정공고][서울지역본부] 기존주택 등 매입임대주택 예비입주자 모집공고
# 19    (SH)2025년 1차 장기미임대 매입임대주택 입주자 모집공고(2025.02.21.)
# Name: 파일명, dtype: object
